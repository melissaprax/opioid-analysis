# %% [markdown]
# ### Goal: Perform a one-way ANOVA on Opioid Mortality Rate with regions as the Groups

# %%
# Dependencies and Setup
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as sts
import seaborn

# %% [markdown]
# ### Import opioid mortality rate dataset

# %%
health04_S_file_path = "../Resources/Health04/Health04_S.csv"
mortality_data = pd.read_csv(health04_S_file_path)
mortality_df = pd.DataFrame(mortality_data)
mortality_df.head(3)
# Out:
#   G_STATEFP  STATEFP st_abb  st_name  opPrscRt19  prMisuse19  odMortRt14  \
# 0       G01        1     AL  Alabama        39.1        4.55        15.2
# 1       G02        2     AK   Alaska        85.8        3.99        16.8
# 2       G04        4     AZ  Arizona        80.9        3.80        18.2
#
#    odMortRt15  odMortRt16  odMortRt17  odMortRt18  odMortRt19  odMortRtAv
# 0        15.7        16.2        18.0        16.6        16.3       16.33
# 1        16.0        16.8        20.2        14.6        17.8       17.03
# 2        19.0        20.3        22.2        23.8        26.8       21.72

# %% [markdown]
# ### Create a dataframe with state abbreviation and opioid mortality rate from mortality_data

# %%
mort_df = mortality_df.loc[:,['st_abb', 'odMortRtAv']]
mort_df = mort_df.rename(columns={'st_abb' : 'STATE', 'odMortRtAv' : 'odMortRtAv'})
mort_df.head(5)
# Out:
#   STATE  odMortRtAv
# 0    AL       16.33
# 1    AK       17.03
# 2    AZ       21.72
# 3    AR       14.18
# 4    CA       12.18

# %% [markdown]
# ### Import region dataset

# %%
region_file_path = "../Resources/Geographic/state_region.csv"
region_data = pd.read_csv(region_file_path)
region_df = pd.DataFrame(region_data).loc[:,['State Code', 'Region', 'Division']].rename(columns={'State Code' : 'STATE', 'Region' : 'REGION', 'Division' : 'DIVISION'})
region_df.head(5)
# Out:
#   STATE REGION            DIVISION
# 0    AK   West             Pacific
# 1    AL  South  East South Central
# 2    AR  South  West South Central
# 3    AZ   West            Mountain
# 4    CA   West             Pacific

# %% [markdown]
# ### Merge mort and region dfs

# %%
mort_region_df = pd.merge(region_df, mort_df, on="STATE", how="inner")
df = mort_region_df.copy()
df
# Out:
#    STATE     REGION            DIVISION  odMortRtAv
# 0     AK       West             Pacific       17.03
# 1     AL      South  East South Central       16.33
# 2     AR      South  West South Central       14.18
# 3     AZ       West            Mountain       21.72
# 4     CA       West             Pacific       12.18
# 5     CO       West            Mountain       16.78
# 6     CT  Northeast         New England       27.23
# 7     DC      South      South Atlantic       21.63
# 8     DE      South      South Atlantic       33.75
# 9     FL      South      South Atlantic       19.48
# 10    GA      South      South Atlantic       13.33
# 11    HI       West             Pacific       13.22
# 12    IA    Midwest  West North Central       10.85
# 13    ID       West            Mountain       15.65
# 14    IL    Midwest  East North Central       19.20
# 15    IN    Midwest  East North Central       21.22
# 16    KS    Midwest  West North Central       15.27
# 17    KY      South  East South Central       30.53
# 18    LA      South  West South Central       23.07
# 19    MA  Northeast         New England       28.03
# 20    MD      South      South Atlantic       29.80
# 21    ME  Northeast         New England       28.03
# 22    MI    Midwest  East North Central       21.08
# 23    MN    Midwest  West North Central       11.83
# 24    MO    Midwest  West North Central       20.37
# 25    MS      South  East South Central       14.88
# 26    MT       West            Mountain       11.85
# 27    NC      South      South Atlantic       17.65
# 28    ND    Midwest  West North Central       13.67
# 29    NE    Midwest  West North Central        9.75
# 30    NH  Northeast         New England       33.60
# 31    NJ  Northeast     Middle Atlantic       23.65
# 32    NM       West            Mountain       25.20
# 33    NV       West            Mountain       23.00
# 34    NY  Northeast     Middle Atlantic       17.15
# 35    OH    Midwest  East North Central       32.77
# 36    OK      South  West South Central       18.37
# 37    OR       West             Pacific       16.53
# 38    PA  Northeast     Middle Atlantic       32.68
# 39    RI  Northeast         New England       27.58
# 40    SC      South      South Atlantic       16.38
# 41    SD    Midwest  West North Central       11.85
# 42    TN      South  East South Central       22.40
# 43    TX      South  West South Central       11.95
# 44    UT       West            Mountain       22.67
# 45    VA      South      South Atlantic       15.30
# 46    VT  Northeast         New England       19.48
# 47    WA       West             Pacific       18.15
# 48    WI    Midwest  East North Central       18.57
# 49    WV      South      South Atlantic       48.52
# 50    WY       West            Mountain       15.13

# %%
df.boxplot("odMortRtAv", by="REGION", figsize=(20, 10))
# Out:
# <AxesSubplot:title={'center':'odMortRtAv'}, xlabel='REGION'>

# %%
regions = list(mort_region_df.REGION.unique())
regions
# Out:
# ['West', 'South', 'Northeast', 'Midwest']

# %%
WEST = df[df["REGION"] == regions[0]]["odMortRtAv"]
SOUTH = df[df["REGION"] == regions[1]]["odMortRtAv"]
NORTHEAST = df[df["REGION"] == regions[2]]["odMortRtAv"]
MIDWEST = df[df["REGION"] == regions[3]]["odMortRtAv"]

# %%
sts.f_oneway(WEST, SOUTH, NORTHEAST, MIDWEST)
# Out:
# F_onewayResult(statistic=3.8315543368069136, pvalue=0.015529712980994927)
